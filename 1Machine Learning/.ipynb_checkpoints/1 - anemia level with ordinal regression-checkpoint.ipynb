# %%
# data_source https://www.kaggle.com/datasets/adeolaadesina/factors-affecting-children-anemia-level/data
import pandas as pd

#df = pd.read_csv("1 - ordinal regression children anemia.csv",sep=";")
df = pd.read_excel("1 - ordinal regression children anemia.xlsx")
df
# Out:
#      Age in 5-year groups Type of place of residence  \
# 0                   25-29                      Urban
# 1                   30-34                      Urban
# 2                   40-44                      Urban
# 3                   20-24                      Rural
# 4                   25-29                      Urban
# ...                   ...                        ...
# 7268                15-19                      Urban
# 7269                30-34                      Rural
# 7270                20-24                      Rural
# 7271                45-49                      Urban
# 7272                20-24                      Urban
#
#      Highest educational level Wealth index combined  \
# 0                    Secondary               Poorest
# 1                       Higher               Richest
# 2                       Higher               Richest
# 3                 No education               Poorest
# 4                    Secondary                Richer
# ...

# %%
df.shape
# Out:
# (7273, 15)

# %% [markdown]
# - **Age in 5-year groups**: 5 yıllık yaş aralıkları (Örnek: 15-19, 20-24, ...)
# - **Type of place of residence**: Katılımcının yaşadığı yerin türü (kentsel/kırsal)
# - **Highest educational level**: Sahip olunan en yüksek eğitim seviyesi (örnek: ilkokul, lise, üniversite)
# - **Wealth index combined**: Varlık endeksi (hanehalkının sosyoekonomik durumuna göre gruplar)
# - **Births in last five years**: Son 5 yılda gerçekleşen doğum sayısı
# - **Age of respondent at 1st birth**: İlk doğumda anne yaşı
# - **Hemoglobin level adjusted for altitude and smoking (g/dl - 1 decimal)**: Rakım ve sigara kullanımına göre ayarlı hemoglobin düzeyi
# - **Anemia level**: Anemi derecesi (örneğin: normal, hafif, orta, şiddetli)
# - **Have mosquito bed net for sleeping**: Hanehalkının sivrisinek cibinliği sahipliği (Evet/Hayır)
# - **Smokes cigarettes**: Sigara içme durumu (Evet/Hayır)
# - **Current marital status**: Güncel medeni durum
# - **Currently residing with husband/partner**: Eşi/partneri ile birlikte yaşama durumu (Evet/Hayır)
# - **When child put to breast**: Çocuk göğüse ne zaman konuldu (doğumdan hemen sonra, birkaç saat sonra vb.)
# - **Had fever in last two weeks**: Son iki haftada ateş geçirdi mi? (Evet/Hayır)
# - **Hemoglobin level adjusted for altitude (g/dl - 1 decimal)**: Yüksekliğe göre ayarlı hemoglobin düzeyi
# - **Anemia level.1**: Anemi derecesinin alternatif bir ölçümü
# - **Taking iron pills, sprinkles or syrup**: Demir desteği (hap, damla, şurup) alımı

# %%
import pandas as pd
for col in df.columns:
    unique_count = df[col].nunique()
    print(f"Sütun: {col} --> Farklı değer sayısı: {unique_count}")
# Out:
# Sütun: Age in 5-year groups --> Farklı değer sayısı: 7
# Sütun: Type of place of residence --> Farklı değer sayısı: 2
# Sütun: Highest educational level --> Farklı değer sayısı: 4
# Sütun: Wealth index combined --> Farklı değer sayısı: 5
# Sütun: Births in last five years --> Farklı değer sayısı: 4
# Sütun: Age of respondent at 1st birth --> Farklı değer sayısı: 33
# Sütun: Hemoglobin level adjusted for altitude and smoking (g/dl - 1 decimal) --> Farklı değer sayısı: 118
# Sütun: Have mosquito bed net for sleeping (from household questionnaire) --> Farklı değer sayısı: 2
# Sütun: Smokes cigarettes --> Farklı değer sayısı: 2
# Sütun: Current marital status --> Farklı değer sayısı: 2
# Sütun: Currently residing with husband/partner --> Farklı değer sayısı: 2
# Sütun: When child put to breast --> Farklı değer sayısı: 38
# Sütun: Had fever in last two weeks --> Farklı değer sayısı: 3
# Sütun: Taking iron pills, sprinkles or syrup --> Farklı değer sayısı: 3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7273 entries, 0 to 7272
# Data columns (total 15 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   Age in 5-year groups                                                   7273 non-null   object
#  1   Type of place of residence                                             7273 non-null   object
#  2   Highest educational level                                              7273 non-null   object
#  3   Wealth index combined                                                  7273 non-null   object
#  4   Births in last five years                                              7273 non-null   int64
#  5   Age of respondent at 1st birth                                         7273 non-null   int64
# ...

# %%
import pandas as pd
import plotly.express as px

# Varsayımsal olarak df veri çerçevenizin mevcut olduğunu kabul edelim.
# df = pd.read_csv("dosyaniz.csv")

# NaN olan hücreleri True olarak işaretle
nan_mask = df.isnull()

# True/False değerlerini 0/1'e dönüştür
nan_mask_int = nan_mask.astype(int)

# Veri seti çok uzun ise, height değerini arttırarak grafiği dikey olarak uzatabilirsiniz.
# Örneğin, height=1500 piksel gibi:
fig = px.imshow(
    nan_mask_int,
    color_continuous_scale=["white", "red"],  # 0 için beyaz, 1 için kırmızı
    aspect="auto",
    height=1000,  # Grafiğin dikey boyutunu arttırıyoruz
    width=800     # Genişliği ayarlayabilirsiniz, verinize göre değiştirin
)

fig.update_layout(
    title="Veri Setindeki Eksik Değerler (NaN) Haritası",
    xaxis_title="Sütunlar",
    yaxis_title="Satırlar"
)

fig.show()

# %%
import pandas as pd
import plotly.express as px

# df veri çerçevenizin mevcut olduğunu varsayalım
# df = pd.read_csv("dosyaniz.csv")

# 1. Hiç NaN olmayan sütunları atla: 
#    df.isnull().any() her sütun için True/False döndürür. True olan sütunlarda en az bir NaN vardır.
cols_with_nan = df.columns[df.isnull().any()]

# Bu sütunları içeren bir alt veri seti oluşturalım
df_with_nan = df[cols_with_nan]

# 2. NaN maskesi oluştur ve 0/1'e dönüştür
nan_mask = df_with_nan.isnull()
nan_mask_int = nan_mask.astype(int)

# 3. Grafiği oluştur: 
fig = px.imshow(
    nan_mask_int,
    color_continuous_scale=["yellow", "red"],  # 0: Veri mevcut, 1: Veri eksik
    aspect="auto",
    height=900,  # Dikey boyut: Çok veriniz varsa artırın
    width=800
)

fig.update_layout(
    title="NaN İçeren Sütunlardaki Eksik Değerler",
    xaxis_title="Sütunlar",
    yaxis_title="Satırlar"
)

fig.show()

# %%
df.describe()
# Out:
#        Births in last five years  Age of respondent at 1st birth  \
# count                7273.000000                     7273.000000
# mean                    1.578716                       20.023787
# std                     0.648174                        4.496070
# min                     1.000000                       12.000000
# 25%                     1.000000                       17.000000
# 50%                     1.000000                       19.000000
# 75%                     2.000000                       23.000000
# max                     4.000000                       45.000000
#
#        Hemoglobin level adjusted for altitude and smoking (g/dl - 1 decimal)  \
# count                                        7273.000000
# mean                                          114.455933
# std                                            15.756432
# min                                            20.000000
# 25%                                           105.000000
# ...

# %%
df.describe(include='all')
# Out:
#        Age in 5-year groups Type of place of residence  \
# count                  7273                       7273
# unique                    7                          2
# top                   25-29                      Rural
# freq                   1958                       4458
# mean                    NaN                        NaN
# std                     NaN                        NaN
# min                     NaN                        NaN
# 25%                     NaN                        NaN
# 50%                     NaN                        NaN
# 75%                     NaN                        NaN
# max                     NaN                        NaN
#
#        Highest educational level Wealth index combined  \
# count                       7273                  7273
# unique                         4                     5
# top                 No education                Middle
# freq                        2813                  1560
# ...

# %%
import missingno as msno
msno.matrix(df)
# Out:
# <Axes: >

# %%
df.isna().sum()
# Out:
# Age in 5-year groups                                                     0
# Type of place of residence                                               0
# Highest educational level                                                0
# Wealth index combined                                                    0
# Births in last five years                                                0
# Age of respondent at 1st birth                                           0
# Hemoglobin level adjusted for altitude and smoking (g/dl - 1 decimal)    0
# Have mosquito bed net for sleeping (from household questionnaire)        0
# Smokes cigarettes                                                        0
# Current marital status                                                   0
# Currently residing with husband/partner                                  0
# When child put to breast                                                 0
# ...

# %%
df
# Out:
#      Age in 5-year groups Type of place of residence  \
# 0                   25-29                      Urban
# 1                   30-34                      Urban
# 2                   40-44                      Urban
# 3                   20-24                      Rural
# 4                   25-29                      Urban
# ...                   ...                        ...
# 7268                15-19                      Urban
# 7269                30-34                      Rural
# 7270                20-24                      Rural
# 7271                45-49                      Urban
# 7272                20-24                      Urban
#
#      Highest educational level Wealth index combined  \
# 0                    Secondary               Poorest
# 1                       Higher               Richest
# 2                       Higher               Richest
# 3                 No education               Poorest
# 4                    Secondary                Richer
# ...

# %%
list(df.columns)
# Out:
# ['Age in 5-year groups',
#  'Type of place of residence',
#  'Highest educational level',
#  'Wealth index combined',
#  'Births in last five years',
#  'Age of respondent at 1st birth',
#  'Hemoglobin level adjusted for altitude and smoking (g/dl - 1 decimal)',
#  'Have mosquito bed net for sleeping (from household questionnaire)',
#  'Smokes cigarettes',
#  'Current marital status',
#  'Currently residing with husband/partner',
#  'When child put to breast',
#  'Had fever in last two weeks',
#  'Taking iron pills, sprinkles or syrup',
#  'Target']

# %%
y = df['Target']
X = df.drop('Target', axis=1)
X
# Out:
#      Age in 5-year groups Type of place of residence  \
# 0                   25-29                      Urban
# 1                   30-34                      Urban
# 2                   40-44                      Urban
# 3                   20-24                      Rural
# 4                   25-29                      Urban
# ...                   ...                        ...
# 7268                15-19                      Urban
# 7269                30-34                      Rural
# 7270                20-24                      Rural
# 7271                45-49                      Urban
# 7272                20-24                      Urban
#
#      Highest educational level Wealth index combined  \
# 0                    Secondary               Poorest
# 1                       Higher               Richest
# 2                       Higher               Richest
# 3                 No education               Poorest
# 4                    Secondary                Richer
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer

ordinal_cols = ['Age in 5-year groups',
                'Highest educational level',
                 'Wealth index combined']


nominal_cols = ['Type of place of residence',
                'Have mosquito bed net for sleeping (from household questionnaire)',
                "Smokes cigarettes",
                "Current marital status",
                "Currently residing with husband/partner",
                "Had fever in last two weeks",
               "Taking iron pills, sprinkles or syrup"]

ordinal_encoder = OrdinalEncoder()
one_hot_encoder = OneHotEncoder(drop='first', sparse=False)

preprocessor = ColumnTransformer(
    transformers=[
        ('ordinal', ordinal_encoder, ordinal_cols),
        ('onehot', one_hot_encoder, nominal_cols)
    ],
    remainder='passthrough'
)

# Veri çevirimini uygula
X_encoded = preprocessor.fit_transform(X)
X_encoded
# Out:
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning:
#
# `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
# array([[2.00e+00, 3.00e+00, 2.00e+00, ..., 2.30e+01, 2.00e+01, 1.04e+02],
#        [3.00e+00, 0.00e+00, 4.00e+00, ..., 2.60e+01, 2.00e+01, 1.00e+00],
#        [5.00e+00, 0.00e+00, 4.00e+00, ..., 3.70e+01, 2.70e+01, 3.60e+03],
#        ...,
#        [1.00e+00, 1.00e+00, 2.00e+00, ..., 1.50e+01, 1.65e+02, 3.60e+03],
#        [6.00e+00, 1.00e+00, 1.00e+00, ..., 1.60e+01, 1.66e+02, 1.02e+02],
#        [1.00e+00, 3.00e+00, 0.00e+00, ..., 1.80e+01, 2.18e+02, 1.00e+00]])

# %%
transformed.shape
# Out:
# (7273, 16)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y_encoded = le.fit_transform(y)

# %%
y_encoded.shape
# Out:
# (7273,)

# %%
import numpy as np
X_array = np.array(X_encoded)
X_array
# Out:
# array([[2.00e+00, 3.00e+00, 2.00e+00, ..., 2.30e+01, 2.00e+01, 1.04e+02],
#        [3.00e+00, 0.00e+00, 4.00e+00, ..., 2.60e+01, 2.00e+01, 1.00e+00],
#        [5.00e+00, 0.00e+00, 4.00e+00, ..., 3.70e+01, 2.70e+01, 3.60e+03],
#        ...,
#        [1.00e+00, 1.00e+00, 2.00e+00, ..., 1.50e+01, 1.65e+02, 3.60e+03],
#        [6.00e+00, 1.00e+00, 1.00e+00, ..., 1.60e+01, 1.66e+02, 1.02e+02],
#        [1.00e+00, 3.00e+00, 0.00e+00, ..., 1.80e+01, 2.18e+02, 1.00e+00]])

# %%
import numpy as np
import pandas as pd
from mord import LogisticIT
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y_encoded, test_size=0.2, random_state=42)

model = LogisticIT()
model.fit(X_train, y_train)  # Eğer burada hala hata alıyorsanız, dağılımı tekrar ayarlayın.

y_pred = model.predict(X_test)

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=3))
# Out:
# Confusion Matrix:
# [[ 19  12 334   0]
#  [296  81  92   0]
#  [  0   0 594   0]
#  [ 27   0   0   0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0      0.056     0.052     0.054       365
#            1      0.871     0.173     0.288       469
#            2      0.582     1.000     0.736       594
#            3      0.000     0.000     0.000        27
#
#     accuracy                          0.477      1455
#    macro avg      0.377     0.306     0.270      1455
# weighted avg      0.532     0.477     0.407      1455
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# ...
